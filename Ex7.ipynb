# %%
import numpy as np
import matplotlib.pyplot as plt

N = 100000
U=np.random.uniform(0,1,N)

x = np.log((np.exp(2)-1)*U +1)

print(x)

X=np.arange(0, 2, 0.1)
fx=np.exp(X)/(np.exp(2)-1)
plt.plot(X,fx)
plt.hist(x,bins=50,density=True)
plt.show()
# Out:
# [1.56086896 1.95633846 0.35370588 ... 1.74935956 0.36734126 1.11488209]
