# %%
import numpy as np
import matplotlib.pyplot as plt

N=100000
x=np.random.uniform(0,1,N)
integral=sum((1-x**2)**1.5)/N
print(integral)
# Out:
# 0.5890928714462326

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 100000
#gerar N amostras uniformes
y = np.random.uniform(0, 1, N)
#Gerar as amostras de g(x)
x = y**(2/5)
#calcular a integral
integral = np.sum((1-x**2)**1.5/2.5*x**1.5) / N
print(f'Integral = {integral:.4f}')
#plotar o grafico
x = np.linspace(0, 1, N)
curve_y = (1-x**2)**1.5
plt.plot(x, curve_y, color='black')
plt.fill_between(x, curve_y, color='blue')
plt.text(0.5, 0.8, f'Integral = {integral:.4f}', fontsize=12, color='red')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Integral = 0.0572
